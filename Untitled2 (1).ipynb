# %%
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %%
# Hours_Studied
hours_studied = [23, 19, 24, 29, 19, 19, 29, 25, 17, 23, 17, 17, 21, 9]

# Attendance
attendance = [84, 64, 98, 89, 92, 88, 84, 78, 94, 98, 80, 97, 83, 82]

# Parental_Involvement
parental_involvement = ["Low", "Low", "Medium", "Low", "Medium", "Medium", "Medium", "Low", "Medium", "Medium", "Low", "Medium", "Medium", "Medium"]

# Access_to_Resources
access_to_resources = ["High", "Medium", "Medium", "Medium", "Medium", "Medium", "Low", "High", "High", "Medium", "High", "High", "Medium", "Medium"]

# Extracurricular_Activities
extracurricular_activities = ["No", "No", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "No", "Yes", "No", "Yes", "Yes", "Yes"]

# Sleep_Hours
sleep_hours = [7, 8, 7, 8, 6, 8, 7, 6, 6, 8, 8, 6, 8, 8]

# Previous_Scores
previous_scores = [73, 59, 91, 98, 65, 89, 68, 50, 80, 71, 88, 87, 97, 72]

# Motivation_Level
motivation_level = ["Low", "Low", "Medium", "Medium", "Medium", "Medium", "Low", "Medium", "High", "Medium", "Medium", "Low", "Low", "Medium"]

# Internet_Access
internet_access = ["Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "No", "Yes", "Yes", "Yes"]

# Tutoring_Sessions
tutoring_sessions = [0, 2, 2, 1, 3, 3, 1, 1, 0, 0, 4, 2, 2, 2]

# Family_Income
family_income = ["Low", "Medium", "Medium", "Medium", "Medium", "Medium", "Low", "High", "Medium", "High", "Medium", "Low", "Medium", "Medium"]

# Teacher_Quality
teacher_quality = ["Medium", "Medium", "Medium", "Medium", "High", "Medium", "Medium", "High", "Low", "High", "High", "High", "Medium", "Medium"]

# School_Type
school_type = ["Public", "Public", "Public", "Public", "Public", "Public", "Private", "Public", "Private", "Public", "Private", "Private", "Public", "Private"]

# Peer_Influence
peer_influence = ["Positive", "Negative", "Neutral", "Negative", "Neutral", "Positive", "Neutral", "Negative", "Neutral", "Positive", "Neutral", "Neutral", "Positive", "Positive"]

# Physical_Activity
physical_activity = [3, 4, 4, 4, 4, 3, 2, 2, 1, 5, 4, 2, 4, 3]

# Learning_Disabilities
learning_disabilities = ["No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No"]

# Parental_Education_Level
parental_education_level = ["High School", "College", "Postgraduate", "High School", "College", "Postgraduate", "High School", "High School", "College", "High School", "College", "High School", "High School", "Postgraduate"]

# Distance_from_Home
distance_from_home = ["Near", "Moderate", "Near", "Moderate", "Near", "Near", "Moderate", "Far", "Near", "Moderate", "Moderate", "Near", "Near", "Near"]

# Gender
gender = ["Male", "Female", "Male", "Male", "Female", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male"]

# Exam_Score
exam_score = [67, 61, 74, 71, 70, 71, 67, 66, 69, 72, 68, 71, 70, 66]

# %%
le = preprocessing.LabelEncoder()
# Converting string into numbers.
hourstudied_encoded=le.fit_transform(hours_studied)
attendance_encoded=le.fit_transform(attendance)
parentalinvolvement=le.fit_transform(parental_involvement)
parentalinvolvement=le.fit_transform(access_to_resources)
parentalinvolvement=le.fit_transform(extracurricular_activities)
parentalinvolvement=le.fit_transform(sleep_hours)
parentalinvolvement=le.fit_transform(previous_scores)
parentalinvolvement=le.fit_transform()
parentalinvolvement=le.fit_transform()
access_to_resources

# %%
features=list(zip(weather_encoded,temp_encoded))

# %%
features_train, features_test,label_train,label_test=train_test_split(features, play_encoded, test_size=0.2, random_state=42)

# %%
model = KNeighborsClassifier(n_neighbors=3, metric='euclidean')

# %%
model.fit(features_train, label_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
predicted = model.predict(features_test)

# %%
print("Prediction:", predicted)
# Out:
# Prediction: [0 1 0]

# %%
conf_mat = confusion_matrix(label_test, predicted)
print("Confusion Matrix:")
print(conf_mat)
# Out:
# Confusion Matrix:
# [[1 0]
#  [1 1]]

# %%
accuracy = accuracy_score(label_test, predicted)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6666666666666666
